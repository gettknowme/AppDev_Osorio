# %% [markdown]
# **EXERCISE 1**
#
# ```Write a program to read through a file and print the contents of the file (line by line) all in upper case.```
#
# from [PEW] E8-1

# %%
file_name = input("Enter the name of the file: ")

try:
    with open(file_name, 'r') as file:
        # Read each line and print it in uppercase
        for line in file:
            print(line.upper(), end='')
except FileNotFoundError:
    print("File not found.")
# Out:
# Enter the name of the file: r programming language
# File not found.

# %% [markdown]
# **EXERCISE 2**
#
# ```Write a program to read through a file and output the number of lines in a file.```
#
# adapted from [PEW]

# %%
name = input("Enter file name: ")
try:
    with open(name) as f:
        print(f"This file has {len(f.readlines())} lines.")
except FileNotFoundError:
    print(f"{name} does not exist.")
# Out:
# Enter file name: R language
# R language does not exist.

# %% [markdown]
# **CHALLENGE**
# from [PEW] E8-2
#
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:
#
#
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %%
name = input("Enter file name: ")

total_confidence = 0
count = 0

with open(name) as f:
    for line in f:
        if line.startswith("X-DSPAM-Confidence:"):
            confidence = float(line[20:].strip())
            total_confidence += confidence
            count += 1

if count > 0:
    average_confidence = total_confidence / count
    print(f"The average spam  is {average_confidence}.")
else:
    print("No spam were found.")
