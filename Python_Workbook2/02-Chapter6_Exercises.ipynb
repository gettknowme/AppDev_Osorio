# %% [markdown]
# **EXERCISE 1**
#
#  Given the code below
#
# ```text = 'Business Analytics' ```
#
# What will the following expressions produce?
# ```
# text[4]
# text[2:4]
# text[:4]
# text[4:]
# text[-2]
# text[-4:-2]
# text[-2:]
# text[:-2]
# ```

# %% [markdown]
# ```
# text[4]: This expression retrieves the character at index 4, which is 'n'.
# text[2:4]: This expression retrieves the substring from index 2 (inclusive) to index 4 (exclusive), which is 'si'.
# text[:4]: This expression retrieves the substring from the beginning up to index 4 (exclusive), which is 'Busi'.
# text[4:]: This expression retrieves the substring from index 4 (inclusive) to the end, which is 'ness Analytics'.
# text[-2]: This expression retrieves the second-to-last character, which is 'c'.
# text[-4:-2]: This expression retrieves the substring from the fourth-to-last character (inclusive) to the second-to-last character (exclusive), which is 'ti'.
# text[-2:]: This expression retrieves the substring from the second-to-last character (inclusive) to the end, which is 'cs'.
# text[:-2]: This expression retrieves the substring from the beginning up to the second-to-last character (exclusive), which is 'Business Analyti'.
# ```

# %% [markdown]
# **EXERCISE 2**
#
# Given the code below:
#
# ```phrase = 'One Ring to rule them all'```
#
# What string slicing expression gives out the following words:
# ```
# 'One '
# 'Ring'
# 'all'
# 'them'
# 'One Ring to rule them all'
# ```

# %% [markdown]
# ```
# phrase = 'One Ring to rule them all'
#
# # 'One '
# phrase[:4]
# # 'Ring'
# phrase[4:8]
# # 'all'
# phrase[-3:]
# # 'them'
# phrase[13:17]
# # 'One Ring to rule them all'
# phrase[:]
# ```
# > Add blockquote

# %% [markdown]
# **CHALLENGE**
#
# Write a program which repeatedly reads a full name, then does the following:
#
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
while True:
    full_name = input("Enter a full name: ")

    if full_name.lower() == 'quit':
        print("Exiting...")
        break
    complete_name = full_name.rstrip().capitalize()
    complete_name = complete_name[:1] + complete_name[1:].lower()

    print("Name:", complete_name)
# Out:
# Enter a full name: rogelynosorio
# Name: Rogelynosorio
# Enter a full name: rogelyn Osorio
# Name: Rogelyn osorio
# Enter a full name: quit
# Exiting...
