# %% [markdown]
# **EXERCISE 1**
#
# Create a dictionary with the following keys and values showing a partial list of Real GDP growth in Annual percent change from IMF
# ```
# China 6.5
# Japan 0.7
# Philippines 6.7
# United States 2.3
# ```

# %%
real_gdp_growth = {
    "China": 6.5,
    "Japan": 0.7,
    "Philippines": 6.7,
    "United States": 2.3
}

# %% [markdown]
# **EXERCISE 2**
#
# ```
# Display all the keys and values from the dictionary you created above
# ```

# %%
real_gdp_growth = {
    "China": 6.5,
    "Japan": 0.7,
    "Philippines": 6.7,
    "United States": 2.3
}
real_gdp_growth
# Out:
# {'China': 6.5, 'Japan': 0.7, 'Philippines': 6.7, 'United States': 2.3}

# %% [markdown]
# **EXERCISE 3**
#
# Write a program that asks the user to enter a line of text and then counts the number of each word that appeared in the line of text. Use the string function ```split()``` to make a list of words from a given string e.g.:
#
# ```word_list = line.split()```
#
# will return a list of words from the string ```line``` and store it in the variable ```word_list.```

# %%
myList = input("Enter a line of text: ")
line_of_text = myList.split()

print(len(line_of_text))
# Out:
# Enter a line of text: Rogelyn Osorio
# 2
