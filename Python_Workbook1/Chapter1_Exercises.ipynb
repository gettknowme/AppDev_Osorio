# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Copy of Chapter1_Exercises.ipynb" "/content/AppDev_Osorio/"
# Out:
# Reinitialized existing Git repository in /content/AppDev_Osorio/.git/

# %% [markdown]
# EXERCISE 1

# %% [markdown]
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
#Print('Hello world!')

print('Hello world!') #the error in this code is the big letter P in the print
# Out:
# Hello world!

# %%
#print'Hello world!')

print('Hello wolrd!') #missing open parenthesis
# Out:
# Hello wolrd!

# %%
#print('Hello world!)

print('Hello wolrd!') #In this line of code the error is ' the missing apostrophe
# Out:
# Hello wolrd!

# %%
#print('Hello world!'')

print('Hello wolrd!') # Will not terminated becasuse of too much apostrophe
# Out:
# Hello wolrd!

# %% [markdown]
# EXERCISE 2

# %%
x = 43
x = x + 1
print(x)

#44
# Out:
# 44

# %% [markdown]
# EXERCISE 3

# %%
x = 43
x = x + 1
print(x)

#The error is in the line 2,the big letter X is undefined
# Out:
# 44
