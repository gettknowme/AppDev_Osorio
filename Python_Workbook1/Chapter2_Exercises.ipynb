# %% [markdown]
# CHAPTER 2 - Variables, Expressions, and Statements

# %% [markdown]
# **Exercise 1**
#
# Write a program that uses input to prompt a user for their name and then welcomes them.

# %%
name = input("Enter your name: ")
print("Hello, "  + name)
# Out:
# Enter your name: Rogelyn
# Hello, Rogelyn

# %% [markdown]
# **Exercise 2**
#
# Write a program to prompt the user for hours and rate per hour to compute gross pay.

# %%
hours = float(input("Enter hours: "))
rate = float(input("Enter rate: "))
pay = hours * rate
print("Pay: ", pay)
# Out:
# Enter hours: 35
# Enter rate: 2.75
# Pay:  96.25

# %% [markdown]
# **Exercise 3**
#
# Assume that we execute the following assignment statements:

# %%
width = 17
height = 12.0
print("width =", width)
print("height =", height)
# Out:
# width = 17
# height = 12.0

# %% [markdown]
# ANSWER: the variable width would be assigned the integer value 17, and the variable height would be assigned the floating-point value 12.0.

# %% [markdown]
# For each of the following expressions, write the value of the expression and the type (of the value of the expression).
# ```
# width//2
# width/2.0
# height/3
# 1 + 2 * 5
# ```

# %%
width = 17
height = 12.0

x = width//2
w = width/2.0
h = height/3
r = 1 + 2 * 5

print("width",x, type(x))
print("width",w, type(w))
print("Height",h, type(h))
print("Result",r, type(r))
# Out:
# width 8 <class 'int'>
# width 8.5 <class 'float'>
# Height 4.0 <class 'float'>
# Result 11 <class 'int'>

# %% [markdown]
# ANSWER:

# %% [markdown]
# **Exercise 4**
#
# Write a program that uses input to prompt a user for a number and then outputs the square of the number

# %%
number = int(input("Enter a number: "))
square = number ** 2
print("The square of", number, "is", square)
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# **CHALLENGE**
#
# Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

# %%
celsius = float(input("Enter the temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"The temperature in Fahrenheit is {fahrenheit} degrees.")
# Out:
# Enter the temperature in Celsius: 32
# The temperature in Fahrenheit is 89.6 degrees.
